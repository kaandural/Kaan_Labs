# %%
import config
import pandas as pd
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials


#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
from IPython.display import IFrame

def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
playlist = sp.user_playlist_tracks("beeeeetle99", "0HGgRYeZ9MPc75Uu0nOFZV")

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/0HGgRYeZ9MPc75Uu0nOFZV/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-07-07T22:36:40Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ellengracehayward'},
#     'href': 'https://api.spotify.com/v1/users/ellengracehayward',
#     'id': 'ellengracehayward',
#     'type': 'user',
#     'uri': 'spotify:user:ellengracehayward'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2iEvnFsWxR0Syqu2JNopAd'},
#        'href': 'https://api.spotify.com/v1/artists/2iEvnFsWxR0Syqu2JNopAd',
#        'id': '2iEvnFsWxR0Syqu2JNopAd',
#        'name': 'Smash Mouth',
#        'type': 'artist',
#        'uri': 'spotify:artist:2iEvnFsWxR0Syqu2JNopAd'}],
#      'available_markets': [],
# ...

# %%
tracks = get_playlist_tracks("beeeeetle99", "0HGgRYeZ9MPc75Uu0nOFZV")

# %%
track_list_id = []
for i in tracks:
    track_list_id.append(i["track"]["id"])

# %%
playlist = sp.user_playlist_tracks("beeeeetle99", "0HGgRYeZ9MPc75Uu0nOFZV")

# %%
tracks
# Out:
# [{'added_at': '2023-07-07T22:36:40Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ellengracehayward'},
#    'href': 'https://api.spotify.com/v1/users/ellengracehayward',
#    'id': 'ellengracehayward',
#    'type': 'user',
#    'uri': 'spotify:user:ellengracehayward'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2iEvnFsWxR0Syqu2JNopAd'},
#       'href': 'https://api.spotify.com/v1/artists/2iEvnFsWxR0Syqu2JNopAd',
#       'id': '2iEvnFsWxR0Syqu2JNopAd',
#       'name': 'Smash Mouth',
#       'type': 'artist',
#       'uri': 'spotify:artist:2iEvnFsWxR0Syqu2JNopAd'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/44zMHQz2GkFUEifL4DuDNY'},
#     'href': 'https://api.spotify.com/v1/albums/44zMHQz2GkFUEifL4DuDNY',
#     'id': '44zMHQz2GkFUEifL4DuDNY',
#     'images': [{'height': 640,
# ...

# %%
playlist["items"][0]
# Out:
# {'added_at': '2023-07-07T22:36:40Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ellengracehayward'},
#   'href': 'https://api.spotify.com/v1/users/ellengracehayward',
#   'id': 'ellengracehayward',
#   'type': 'user',
#   'uri': 'spotify:user:ellengracehayward'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2iEvnFsWxR0Syqu2JNopAd'},
#      'href': 'https://api.spotify.com/v1/artists/2iEvnFsWxR0Syqu2JNopAd',
#      'id': '2iEvnFsWxR0Syqu2JNopAd',
#      'name': 'Smash Mouth',
#      'type': 'artist',
#      'uri': 'spotify:artist:2iEvnFsWxR0Syqu2JNopAd'}],
#    'available_markets': [],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/44zMHQz2GkFUEifL4DuDNY'},
#    'href': 'https://api.spotify.com/v1/albums/44zMHQz2GkFUEifL4DuDNY',
#    'id': '44zMHQz2GkFUEifL4DuDNY',
#    'images': [{'height': 640,
# ...

# %%
audio_list = []
for i in track_list_id:
    audio_list.append(sp.audio_features(i)[0])

# %%
audio_list
# Out:
# [{'danceability': 0.731,
#   'energy': 0.867,
#   'key': 11,
#   'loudness': -5.881,
#   'mode': 1,
#   'speechiness': 0.032,
#   'acousticness': 0.0395,
#   'instrumentalness': 0,
#   'liveness': 0.0861,
#   'valence': 0.776,
#   'tempo': 104.019,
#   'type': 'audio_features',
#   'id': '3cfOd4CMv2snFaKAnMdnvK',
#   'uri': 'spotify:track:3cfOd4CMv2snFaKAnMdnvK',
#   'track_href': 'https://api.spotify.com/v1/tracks/3cfOd4CMv2snFaKAnMdnvK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3cfOd4CMv2snFaKAnMdnvK',
#   'duration_ms': 200373,
#   'time_signature': 4},
#  {'danceability': 0.542,
#   'energy': 0.905,
#   'key': 9,
#   'loudness': -5.653,
#   'mode': 1,
#   'speechiness': 0.054,
#   'acousticness': 0.00172,
#   'instrumentalness': 0.0104,
#   'liveness': 0.136,
#   'valence': 0.374,
#   'tempo': 153.398,
#   'type': 'audio_features',
#   'id': '5A1FmxbYVRZKy4nc16MAue',
#   'uri': 'spotify:track:5A1FmxbYVRZKy4nc16MAue',
# ...

# %%
df = pd.DataFrame(audio_list)
df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.731   0.867   11    -5.881     1       0.0320       0.03950
# 1           0.542   0.905    9    -5.653     1       0.0540       0.00172
# 2           0.395   0.922    1    -2.176     1       0.3750       0.19000
# 3           0.352   0.911    1    -5.230     1       0.0747       0.00121
# 4           0.679   0.903    4    -4.914     1       0.0463       0.33300
# ..            ...     ...  ...       ...   ...          ...           ...
# 319         0.572   0.786    8    -8.469     1       0.0642       0.51900
# 320         0.867   0.857    9    -5.892     1       0.0663       0.13000
# 321         0.815   0.724    1    -5.656     1       0.0716       0.03920
# 322         0.642   0.591   11    -5.679     0       0.0375       0.00172
# 323         0.690   0.636    9    -6.028     0       0.0457       0.02030
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# ## repeating for a new playlist

# %%
tracks_2 = get_playlist_tracks("skye", "0RH319xCjeU8VyTSqCF6M4")

# %%
track_list_id_2 = []
for i in tracks_2:
    track_list_id_2.append(i["track"]["id"])

# %%
audio_list_2 = []
for i in track_list_id_2:
    audio_list_2.append(sp.audio_features(i)[0])

# %%
df_2 = pd.DataFrame(audio_list_2)
df_2
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.647   0.822    5    -4.662     0       0.1830       0.21900
# 1           0.666   0.830    0    -5.715     1       0.0751       0.01230
# 2           0.702   0.825    6    -3.787     0       0.0601       0.00883
# 3           0.836   0.743   10    -6.305     0       0.0653       0.09740
# 4           0.768   0.714   10    -5.110     1       0.0401       0.35200
# ..            ...     ...  ...       ...   ...          ...           ...
# 98          0.755   0.837    2    -2.718     0       0.1420       0.09910
# 99          0.711   0.700    1    -4.805     0       0.0460       0.00498
# 100         0.720   0.791    1    -4.689     1       0.1240       0.03840
# 101         0.844   0.629    0    -4.558     1       0.0897       0.33900
# 102         0.838   0.740   11    -5.261     1       0.1010       0.00627
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# ## concating the playlists

# %%
concat_playlist = df.append(df_2)
concat_playlist
# Out:
# /var/folders/g_/bb6gz93s0kq9d0zgw1cdzmww0000gn/T/ipykernel_97341/4255719143.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   concat_playlist = df.append(df_2)
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.731   0.867   11    -5.881     1       0.0320       0.03950
# 1           0.542   0.905    9    -5.653     1       0.0540       0.00172
# 2           0.395   0.922    1    -2.176     1       0.3750       0.19000
# 3           0.352   0.911    1    -5.230     1       0.0747       0.00121
# 4           0.679   0.903    4    -4.914     1       0.0463       0.33300
# ..            ...     ...  ...       ...   ...          ...           ...
# 98          0.755   0.837    2    -2.718     0       0.1420       0.09910
# 99          0.711   0.700    1    -4.805     0       0.0460       0.00498
# ...

# %% [markdown]
# ## adding another playlist

# %%
tracks_3 = get_playlist_tracks("spotify", "37i9dQZF1DXdpVGstUksUC")

# %%
track_list_id_3 = []
for i in tracks_3:
    track_list_id_3.append(i["track"]["id"])

# %%
audio_list_3 = []
for i in track_list_id_3:
    audio_list_3.append(sp.audio_features(i)[0])

# %%
df_3 = pd.DataFrame(audio_list_3)
df_3
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.172   0.904   11    -4.831     1       0.0586      0.000054
# 1          0.437   0.390    9    -9.944     1       0.0460      0.630000
# 2          0.237   0.691    0    -8.148     0       0.0420      0.005850
# 3          0.180   0.419    5   -13.268     1       0.0308      0.000127
# 4          0.455   0.919   11    -4.656     1       0.0383      0.000713
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.401   0.900    8    -3.938     1       0.0648      0.000023
# 96         0.359   0.700   11    -5.618     1       0.0332      0.001290
# 97         0.460   0.756    5    -9.251     0       0.0426      0.037100
# 98         0.489   0.828    7    -5.732     1       0.0344      0.000079
# 99         0.191   0.871    3    -5.628     0       0.0730      0.000279
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
concat_playlist_2 = pd.concat([concat_playlist, df_3])

concat_playlist_2
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.731   0.867   11    -5.881     1       0.0320      0.039500
# 1          0.542   0.905    9    -5.653     1       0.0540      0.001720
# 2          0.395   0.922    1    -2.176     1       0.3750      0.190000
# 3          0.352   0.911    1    -5.230     1       0.0747      0.001210
# 4          0.679   0.903    4    -4.914     1       0.0463      0.333000
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.401   0.900    8    -3.938     1       0.0648      0.000023
# 96         0.359   0.700   11    -5.618     1       0.0332      0.001290
# 97         0.460   0.756    5    -9.251     0       0.0426      0.037100
# 98         0.489   0.828    7    -5.732     1       0.0344      0.000079
# 99         0.191   0.871    3    -5.628     0       0.0730      0.000279
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# ## adding another playlist

# %%
tracks_4 = get_playlist_tracks("rodrigo humberto", "1oE3Ccydat4AkQ9mMo4jSs")

# %%
track_list_id_4 = []
for i in tracks_4:
    track_list_id_4.append(i["track"]["id"])

# %%
audio_list_4 = []
for i in track_list_id_4:
    audio_list_4.append(sp.audio_features(i)[0])

# %%
df_4 = pd.DataFrame(audio_list_4)
df_4
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.539   0.583    1    -4.935     0       0.0275        0.1080
# 1          0.439   0.512    8   -12.871     1       0.0514        0.3480
# 2          0.726   0.449    0    -9.206     1       0.0286        0.4870
# 3          0.395   0.252    0   -13.589     1       0.0301        0.8000
# 4          0.382   0.589    9    -7.315     0       0.0267        0.0465
# ..           ...     ...  ...       ...   ...          ...           ...
# 68         0.783   0.836    0    -9.223     0       0.0486        0.3960
# 69         0.533   0.783    7   -10.610     1       0.0366        0.0116
# 70         0.529   0.843    6    -6.908     0       0.0616        0.0628
# 71         0.578   0.654    1   -12.421     0       0.0562        0.1210
# 72         0.286   0.500    1   -14.281     0       0.0357        0.1340
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
concat_playlist_3 = pd.concat([concat_playlist_2, df_4])

concat_playlist_3
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.731   0.867   11    -5.881     1       0.0320       0.03950
# 1          0.542   0.905    9    -5.653     1       0.0540       0.00172
# 2          0.395   0.922    1    -2.176     1       0.3750       0.19000
# 3          0.352   0.911    1    -5.230     1       0.0747       0.00121
# 4          0.679   0.903    4    -4.914     1       0.0463       0.33300
# ..           ...     ...  ...       ...   ...          ...           ...
# 68         0.783   0.836    0    -9.223     0       0.0486       0.39600
# 69         0.533   0.783    7   -10.610     1       0.0366       0.01160
# 70         0.529   0.843    6    -6.908     0       0.0616       0.06280
# 71         0.578   0.654    1   -12.421     0       0.0562       0.12100
# 72         0.286   0.500    1   -14.281     0       0.0357       0.13400
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# ## another one

# %%
tracks_5 = get_playlist_tracks("spotify", "37i9dQZF1DWXRqgorJj26U")

# %%
track_list_id_5 = []
for i in tracks_5:
    track_list_id_5.append(i["track"]["id"])

# %%
audio_list_5 = []
for i in track_list_id_5:
    audio_list_5.append(sp.audio_features(i)[0])

# %%
df_5 = pd.DataFrame(audio_list_5)
df_5
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.464   0.795    1    -9.267     1       0.0926      0.049300
# 1           0.450   0.877    9    -6.403     1       0.0532      0.011800
# 2           0.392   0.476    1    -7.583     1       0.0249      0.397000
# 3           0.215   0.927    9    -7.327     1       0.0452      0.000273
# 4           0.933   0.528    5    -6.472     0       0.1610      0.112000
# ..            ...     ...  ...       ...   ...          ...           ...
# 195         0.438   0.805    8    -6.237     1       0.0624      0.002550
# 196         0.595   0.996    2    -3.418     1       0.0599      0.195000
# 197         0.615   0.910   11    -4.248     1       0.0347      0.500000
# 198         0.532   0.767    7    -5.509     1       0.0574      0.002870
# 199         0.730   0.487    4   -10.991     1       0.0303      0.258000
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
concat_playlist_4 = pd.concat([concat_playlist_3, df_5])

concat_playlist_4
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.731   0.867   11    -5.881     1       0.0320       0.03950
# 1           0.542   0.905    9    -5.653     1       0.0540       0.00172
# 2           0.395   0.922    1    -2.176     1       0.3750       0.19000
# 3           0.352   0.911    1    -5.230     1       0.0747       0.00121
# 4           0.679   0.903    4    -4.914     1       0.0463       0.33300
# ..            ...     ...  ...       ...   ...          ...           ...
# 195         0.438   0.805    8    -6.237     1       0.0624       0.00255
# 196         0.595   0.996    2    -3.418     1       0.0599       0.19500
# 197         0.615   0.910   11    -4.248     1       0.0347       0.50000
# 198         0.532   0.767    7    -5.509     1       0.0574       0.00287
# 199         0.730   0.487    4   -10.991     1       0.0303       0.25800
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# ## last one

# %%
tracks_6 = get_playlist_tracks("spotify", "37i9dQZF1DXbITWG1ZJKYt")

# %%
track_list_id_6 = []
for i in tracks_6:
    track_list_id_6.append(i["track"]["id"])

# %%
audio_list_6 = []
for i in track_list_id_6:
    audio_list_6.append(sp.audio_features(i)[0])

# %%
df_6 = pd.DataFrame(audio_list_6)
df_6
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.271  0.1650    5   -20.652     1       0.0351         0.729
# 1           0.746  0.2430    4   -15.134     0       0.1230         0.829
# 2           0.349  0.1820    5   -13.507     1       0.0310         0.920
# 3           0.454  0.2600    8   -13.193     0       0.0401         0.539
# 4           0.262  0.3560    0    -8.031     0       0.0303         0.613
# ..            ...     ...  ...       ...   ...          ...           ...
# 295         0.505  0.3030    8   -14.714     1       0.0738         0.807
# 296         0.529  0.3280    0   -16.845     0       0.0487         0.643
# 297         0.664  0.2070    8   -13.325     1       0.0525         0.817
# 298         0.308  0.7410    6    -7.919     1       0.0593         0.773
# 299         0.479  0.0453    0   -18.651     0       0.0364         0.911
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
concat_playlist_5 = pd.concat([concat_playlist_4, df_6])

concat_playlist_5
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.731  0.8670   11    -5.881     1       0.0320       0.03950
# 1           0.542  0.9050    9    -5.653     1       0.0540       0.00172
# 2           0.395  0.9220    1    -2.176     1       0.3750       0.19000
# 3           0.352  0.9110    1    -5.230     1       0.0747       0.00121
# 4           0.679  0.9030    4    -4.914     1       0.0463       0.33300
# ..            ...     ...  ...       ...   ...          ...           ...
# 295         0.505  0.3030    8   -14.714     1       0.0738       0.80700
# 296         0.529  0.3280    0   -16.845     0       0.0487       0.64300
# 297         0.664  0.2070    8   -13.325     1       0.0525       0.81700
# 298         0.308  0.7410    6    -7.919     1       0.0593       0.77300
# 299         0.479  0.0453    0   -18.651     0       0.0364       0.91100
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# ## very last one

# %%
tracks_7 = get_playlist_tracks("spotify", "37i9dQZF1DX9L93gfg5cPa")

# %%
track_list_id_7 = []
for i in tracks_7:
    track_list_id_7.append(i["track"]["id"])

# %%
audio_list_7 = []
for i in track_list_id_7:
    audio_list_7.append(sp.audio_features(i)[0])

# %%
df_7 = pd.DataFrame(audio_list_7)
df_7
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.778   0.632    2    -5.600     0       0.0493       0.27400
# 1           0.514   0.730    1    -5.934     1       0.0598       0.00146
# 2           0.835   0.679    7    -5.329     0       0.0364       0.58300
# 3           0.548   0.816    0    -4.209     1       0.0465       0.12200
# 4           0.621   0.782    2    -5.548     1       0.0440       0.01250
# ..            ...     ...  ...       ...   ...          ...           ...
# 195         0.824   0.588    6    -6.400     0       0.0924       0.69200
# 196         0.724   0.436    0    -9.321     1       0.0282       0.57600
# 197         0.765   0.574    6    -4.360     0       0.0926       0.18200
# 198         0.646   0.471   10    -9.247     1       0.1570       0.12200
# 199         0.667   0.287    0    -9.718     1       0.0334       0.76900
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
concat_playlist_6 = pd.concat([concat_playlist_5, df_7])

concat_playlist_6
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.731   0.867   11    -5.881     1       0.0320       0.03950
# 1           0.542   0.905    9    -5.653     1       0.0540       0.00172
# 2           0.395   0.922    1    -2.176     1       0.3750       0.19000
# 3           0.352   0.911    1    -5.230     1       0.0747       0.00121
# 4           0.679   0.903    4    -4.914     1       0.0463       0.33300
# ..            ...     ...  ...       ...   ...          ...           ...
# 195         0.824   0.588    6    -6.400     0       0.0924       0.69200
# 196         0.724   0.436    0    -9.321     1       0.0282       0.57600
# 197         0.765   0.574    6    -4.360     0       0.0926       0.18200
# 198         0.646   0.471   10    -9.247     1       0.1570       0.12200
# 199         0.667   0.287    0    -9.718     1       0.0334       0.76900
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# ## last of the last one

# %%
tracks_8 = get_playlist_tracks("spotify", "37i9dQZF1DWTmvXBN4DgpA")

# %%
track_list_id_8 = []
for i in tracks_8:
    track_list_id_8.append(i["track"]["id"])

# %%
audio_list_8 = []
for i in track_list_id_8:
    audio_list_8.append(sp.audio_features(i)[0])

# %%
df_8 = pd.DataFrame(audio_list_8)
df_8
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.414   0.404    0    -9.928     0       0.0499       0.27100
# 1            0.401   0.383    9   -10.048     1       0.0279       0.51000
# 2            0.579   0.508    2    -9.484     1       0.0270       0.00574
# 3            0.334   0.472    0    -8.791     1       0.0277       0.60000
# 4            0.209   0.417    3    -8.740     1       0.0338       0.16400
# ...            ...     ...  ...       ...   ...          ...           ...
# 1994         0.430   0.740   10    -7.072     1       0.0375       0.02120
# 1995         0.577   0.788    4    -6.813     1       0.0309       0.00727
# 1996         0.181   0.241   10   -11.626     1       0.0309       0.90000
# 1997         0.454   0.644    0    -4.446     1       0.0284       0.09840
# 1998         0.561   0.431   10    -8.810     1       0.0578       0.76800
#
# ...

# %%
concat_playlist_7 = pd.concat([concat_playlist_6, df_8])

concat_playlist_7
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.731   0.867   11    -5.881     1       0.0320       0.03950
# 1            0.542   0.905    9    -5.653     1       0.0540       0.00172
# 2            0.395   0.922    1    -2.176     1       0.3750       0.19000
# 3            0.352   0.911    1    -5.230     1       0.0747       0.00121
# 4            0.679   0.903    4    -4.914     1       0.0463       0.33300
# ...            ...     ...  ...       ...   ...          ...           ...
# 1994         0.430   0.740   10    -7.072     1       0.0375       0.02120
# 1995         0.577   0.788    4    -6.813     1       0.0309       0.00727
# 1996         0.181   0.241   10   -11.626     1       0.0309       0.90000
# 1997         0.454   0.644    0    -4.446     1       0.0284       0.09840
# 1998         0.561   0.431   10    -8.810     1       0.0578       0.76800
#
# ...

# %% [markdown]
# ## machine learning part

# %%
concat_playlist_7.describe()
# Out:
#        danceability       energy          key     loudness         mode  \
# count   3299.000000  3299.000000  3299.000000  3299.000000  3299.000000
# mean       0.548165     0.604658     5.061534    -8.776563     0.680812
# std        0.158277     0.236929     3.560467     4.069026     0.466233
# min        0.121000     0.007560     0.000000   -27.331000     0.000000
# 25%        0.437000     0.431000     2.000000   -10.991000     0.000000
# 50%        0.551000     0.640000     5.000000    -7.900000     1.000000
# 75%        0.662500     0.802000     8.000000    -5.788000     1.000000
# max        0.965000     0.996000    11.000000    -1.190000     1.000000
#
#        speechiness  acousticness  instrumentalness     liveness      valence  \
# count  3299.000000   3299.000000       3299.000000  3299.000000  3299.000000
# mean      0.055196      0.293525          0.069659     0.187117     0.513111
# std       0.050521      0.307630          0.195753     0.160802     0.246511
# ...

# %%
#dropping out the unnecesarry columns

playlist_with_id = concat_playlist_7.drop(["type", "uri", "track_href", "analysis_url", "duration_ms", "time_signature","mode"], axis=1)

playlist_with_id
# Out:
#       danceability  energy  key  loudness  speechiness  acousticness  \
# 0            0.731   0.867   11    -5.881       0.0320       0.03950
# 1            0.542   0.905    9    -5.653       0.0540       0.00172
# 2            0.395   0.922    1    -2.176       0.3750       0.19000
# 3            0.352   0.911    1    -5.230       0.0747       0.00121
# 4            0.679   0.903    4    -4.914       0.0463       0.33300
# ...            ...     ...  ...       ...          ...           ...
# 1994         0.430   0.740   10    -7.072       0.0375       0.02120
# 1995         0.577   0.788    4    -6.813       0.0309       0.00727
# 1996         0.181   0.241   10   -11.626       0.0309       0.90000
# 1997         0.454   0.644    0    -4.446       0.0284       0.09840
# 1998         0.561   0.431   10    -8.810       0.0578       0.76800
#
#       instrumentalness  liveness  valence    tempo                      id
# ...

# %%
# dropping out the id before train k-means & dropping duplicates
playlist_with_id = playlist_with_id.drop_duplicates()
train_df = train_df.drop_duplicates()
train_df = playlist_with_id.drop(["id"], axis = 1)

train_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 3
#       1 # dropping out the id before train k-means & dropping duplicates
#       2 playlist_with_id = playlist_with_id.drop_duplicates()
# ----> 3 train_df = train_df.drop_duplicates()
#       4 train_df = playlist_with_id.drop(["id"], axis = 1)
#       6 train_df
#
# NameError: name 'train_df' is not defined

# %%
#training the dataframe called train_df

scaler = StandardScaler()
scaler.fit(train_df)
train_df_scaled = scaler.transform(train_df)
X_scaled_df = pd.DataFrame(train_df, columns = train_df.columns)

print()
display(X_scaled_df.head())

#he is trained now. very fit.

# %%
X_scaled_df.describe()

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=1234)
kmeans.fit(X_scaled_df)

# %%
K = range(2, 21)
inertia = []

for k in K:
    print("Training a K-Means model with {} clusters! ".format(k))
    print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)
    inertia.append(kmeans.inertia_)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')

#did not like the result. changing to another method.

# %%
#Silouhette
from sklearn.metrics import silhouette_score
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)

    silhouette.append(silhouette_score(X_scaled_df, kmeans.predict(X_scaled_df)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette Method showing the optimal k')

#13 clusters can be choosen. Let's try another method.

# %%
from yellowbrick.cluster import SilhouetteVisualizer
model = KMeans(10, random_state=42)
visualizer = SilhouetteVisualizer(model, colors='yellowbrick')
visualizer.fit(X_scaled_df)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

#decided to have 10 clusters

# %%
X_scaled_df

# %%
# Fit K-means clustering with k=10
import pickle
k = 10
kmeans = KMeans(n_clusters=k, random_state=1234)
kmeans.fit(X_scaled_df)


silhouette = silhouette_score(X_scaled_df, kmeans.predict(X_scaled_df))
print(f"K-means clustering with k={k} completed.")
print("Silhouette Score:", silhouette)

#silhoutte score indicates that there might be overlapping clusters :(

# %%
clusters = kmeans.predict(X_scaled_df)
#clusters
pd.Series(clusters).value_counts().sort_index()

# %%
#adding the clusters column
playlist_with_id["cluster"] = clusters
playlist_with_id

# %%
playlist_without_id.drop("key",axis = 1)

# %%
playlist_with_id

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
from IPython.display import IFrame

def play_song(user_df):
    return IFrame(src="https://open.spotify.com/embed/track/"+"id",
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
def extract(query):
    results = sp.search(q=user_song,limit=1,market="GB")
    song_audio_features = spotify.audio_features
    return song_audio_features

# %%
X_scaled_df

# %%
song_audio_features

# %%
X_scaled_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 X_scaled_df
#
# NameError: name 'X_scaled_df' is not defined

# %%
#gen Z style talking music recommender
df_top_100 = pd.read_csv('df_top_100.csv')
user_song = input("Enter a song yo! ")
user_song = user_song.lower()

if user_song in df_top_100['songs'].values:
    recommended_song = df_top_100.sample()['songs'].values[0]
    recommended_song = recommended_song.capitalize()  
    print(f"Yo, we got a sick recommendation for you: {recommended_song}!")
else:
    answer = input("Yo, do you want some lit recommendations based on your song? Type 'yeah' or 'nah': ")
    if answer == 'yeah':
        results = sp.search(q=user_song, limit=1, market="GB")
        track_id = results['tracks']["items"][0]["id"]
        audio_features = pd.DataFrame(sp.audio_features(track_id)[0], index=[0])

        song_audio_features = scaler.transform(audio_features.drop(['duration_ms', "type", "id", "uri", "track_href", "analysis_url", "time_signature", 'mode'], axis=1))
        user_cluster = kmeans.predict(song_audio_features)[0]
        playlist_filtered = playlist_with_id[playlist_with_id["cluster"] == user_cluster].reset_index()


        print("Dis' the song you asked for")
        display(IFrame(src="https://open.spotify.com/embed/track/" + track_id, width="320", height="80",
            frameborder="0",
            allowtransparency="true",
            allow="encrypted-media"))

        confirm_song = input("Dis' the the song you asked for? Type 'yeah' or 'nah': ")
        if confirm_song == 'yeah':
            recommendation = playlist_filtered["id"][random.randint(0, len(playlist_filtered) - 1)]
            print("Yo, here's a fire recommendation:")
            display(IFrame(src="https://open.spotify.com/embed/track/" + recommendation, width="320", height="80",
                frameborder="0",
                allowtransparency="true",
                allow="encrypted-media"))
        else:
            print("Alright, no worries. Enjoy your music journey!")
    else:
        print("Alright, no worries. Stay groovy!")
# Out:
# Enter a song yo! yes
# Yo, do you want some lit recommendations based on your song? Type 'yeah' or 'nah': yeah
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 17
#      14 track_id = results['tracks']["items"][0]["id"]
#      15 audio_features = pd.DataFrame(sp.audio_features(track_id)[0], index=[0])
# ---> 17 song_audio_features = scaler.transform(audio_features.drop(['duration_ms', "type", "id", "uri", "track_href", "analysis_url", "time_signature", 'mode'], axis=1))
#      18 user_cluster = kmeans.predict(song_audio_features)[0]
#      19 playlist_filtered = playlist_with_id[playlist_with_id["cluster"] == user_cluster].reset_index()
#
# NameError: name 'scaler' is not defined
